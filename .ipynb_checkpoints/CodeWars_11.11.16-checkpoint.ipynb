# %% [markdown]
# # DNA

# %%
dna = 'ATCG'
def DNA_strand(dna):
    dna = dna.replace('A', 't').replace('C', 'g').replace('G','c').replace('T','a')
    return dna.upper()
print DNA_strand(dna)
# Out:
# TAGC

# %%
dna = 'ATCG'
def DNA_strand(dna):
    dnadict = {'A':'T', 'C':'G', 'G':'C', 'T':'A'}
    return ''.join([dnadict[cnt] for cnt in dna])
    #for cnt in dna:
    #    print dnadict[cnt]
print DNA_strand(dna)
# Out:
# TAGC

# %% [markdown]
# # duplicate encode

# %%
count = 0
def duplicate_encode(word):
    for i in range(len(word)):
        if i in range(len(word)):
            print word[i]
            if any(word[i] in word for word in word):
                return word.replace(word[i],')')
            else:
                return word.replace(word[i],'(')
            
duplicate_encode('did')
# Out:
# d
# ')i)'

# %%
def duplicate_encode(word):
    word = word.lower()
    for i in range(len(word)):
        for x in word:
            print x
            if any(x in word for x in word):
                return word.replace(x,')')
            elif any(x not in word for x in word):
                return word.replace(x,'(')
duplicate_encode('Success')
# Out:
# s
# ')ucce))'

# %%
def duplicate_encode(word):
    word = word.lower()
    for i in range(len(word)):
        i = 0
        while i < len(word):
            for char in word[i]:
                if any(char in word[i] for char in word[i]):
                    count = word[i].count(char)
                    if count > 1:
                        print char, count
                        return word.replace(char,')')
                    elif count < 1:
                        return word.replace(char,'(') 
duplicate_encode('Success')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-211-e185c6c779fc> in <module>()
#      12                     elif count < 1:
#      13                         return word.replace(char,'(')
# ---> 14 duplicate_encode('Success')
#
# <ipython-input-211-e185c6c779fc> in duplicate_encode(word)
#       6             for char in word[i]:
#       7                 if any(char in word[i] for char in word[i]):
# ----> 8                     count = word[i].count(char)
#       9                     if count > 1:
#      10                         print char, count
#
# KeyboardInterrupt:

# %%
def duplicate_encode(word):
    word = word.lower()
    for i in range(len(word)):
        if i < range(len(word))
        i = i + 1
        print i
         
duplicate_encode('Success')
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
def duplicate_encode(word):
    word = word.lower()
    for i in range(len(word)):
        print i
        if i < range(len(word)):
            print i
            count = word[i].count(word)
            if count > 1:
                return word.replace(word[i],')')
            elif count < 1:
                return word.replace(word[i],'(')   
duplicate_encode('Success')

# %%
count = {}
def duplicate_encode(word):
    word = word.lower()
    for char in word:
        if count.has_key(char):
            return word.replace(char,')')
        else:
            return word.replace(char,'(')
duplicate_encode('Success')
# Out:
# s
# '(ucce(('

# %%
def duplicate_encode(word):
    word = word.lower()
    for char in word:
    if char in set(word):
        
duplicate_encode('Success')
# Out:
# set(['e', 's', 'u', 'c'])

# %% [markdown]
# # Even or Odd:
# Create a function that takes an integer as an argument and returns "Even" for even numbers or "Odd" for odd numbers.

# %%
def even_or_odd(number):
    if number%2 == 0:
        return "Even"
    elif number%2 != 0:
        return "Odd"

even_or_odd(7)
# Out:
# 'Odd'

# %%
def even_or_odd(number):
    return 'Even' if number%2 == 0 else 'Odd'

even_or_odd(0)
# Out:
# 'Even'

# %% [markdown]
# # Find the next perfect square!
#
# You might know some pretty large perfect squares. But what about the NEXT one?
# Complete the findNextSquare method that finds the next integral perfect square after the one passed as a parameter. Recall that an integral perfect square is an integer n such that sqrt(n) is also an integer.
# If the parameter is itself not a perfect square, than -1 should be returned. You may assume the parameter is positive.

# %%
def find_next_square(sq):
    # Return the next square if sq is a square, -1 otherwise
    try:
        if sq%(sq**(0.5)) == 0:
            #print "true", sq**(.50)
            sq_new = (sq**(0.5) + 1)**2
            return sq_new
        else:
            return -1
    except 'ZeroDivisionError: float modulo':
        pass

find_next_square(121)
# Out:
# 144.0

# %%
def find_next_square(sq):
    root = sq**(0.5)
    if root.is_integer():
        return (root+1)**2
    return -1
find_next_square(144)
# Out:
# 169.0

# %%
def find_next_square(sq):
    x = sq**(0.5)
    print x
    return -1 if x%1 else (x+1)**2 
find_next_square(121)
# Out:
# 11.0
# 144.0

# %%
import math
def find_next_square(sq):
    x = (float(math.sqrt(sq)))
    if x%1 == 0:
        return pow(int(x)+1,2)
    return -1
find_next_square(122)
# Out:
# -1
